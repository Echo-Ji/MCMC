# %%
# %matplotlib inline
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os
os.environ['TF_C_API_GRAPH_CONSTRUCTION']='0'
import edward as ed
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

from edward.models import Normal

plt.style.use('ggplot')

# %%
def build_toy_dataset(N=50, noise_std=0.1):
    x = np.linspace(-3, 3, num=N)
    y = np.cos(x) + np.random.normal(0, noise_std, size=N)
    x = x.astype(np.float32).reshape((N, 1))
    y = y.astype(np.float32)
    return x, y


def neural_network(x, W_0, W_1, b_0, b_1):
    h = tf.tanh(tf.matmul(x, W_0) + b_0)
    h = tf.matmul(h, W_1) + b_1
    return tf.reshape(h, [-1])

# %%
ed.set_seed(43)

N = 50  # number of data points
D = 1   # number of features

x_train, y_train = build_toy_dataset(N)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-26-8931bfa418a7> in <module>()
# ----> 1 ed.set_seed(43)
#       2
#       3 N = 50  # number of data points
#       4 D = 1   # number of features
#       5
#
# /home/jjh/anaconda3/lib/python3.5/site-packages/edward/util/graphs.py in set_seed(x)
#      66   node_names = list(six.iterkeys(tf.get_default_graph()._nodes_by_name))
#      67   if len(node_names) > 0 and node_names != ['keras_learning_phase']:
# ---> 68     raise RuntimeError("Seeding is not supported after initializing "
#      69                        "part of the graph. "
#      70                        "Please move set_seed to the beginning of your code.")
#
# RuntimeError: Seeding is not supported after initializing part of the graph. Please move set_seed to the beginning of your code.

# %%
W_0 = Normal(loc=tf.zeros([D, 2]), scale=tf.ones([D, 2]))
W_1 = Normal(loc=tf.zeros([2, 1]), scale=tf.ones([2, 1]))
b_0 = Normal(loc=tf.zeros(2), scale=tf.ones(2))
b_1 = Normal(loc=tf.zeros(1), scale=tf.ones(1))

x = x_train
y = Normal(loc=neural_network(x, W_0, W_1, b_0, b_1),
           scale=0.1 * tf.ones(N))

# %%
qW_0 = Normal(loc=tf.get_variable("qW_0/loc", [D, 2]),
              scale=tf.nn.softplus(tf.get_variable("qW_0/scale", [D, 2])))
qW_1 = Normal(loc=tf.get_variable("qW_1/loc", [2, 1]),
              scale=tf.nn.softplus(tf.get_variable("qW_1/scale", [2, 1])))
qb_0 = Normal(loc=tf.get_variable("qb_0/loc", [2]),
              scale=tf.nn.softplus(tf.get_variable("qb_0/scale", [2])))
qb_1 = Normal(loc=tf.get_variable("qb_1/loc", [1]),
              scale=tf.nn.softplus(tf.get_variable("qb_1/scale", [1])))

# %%
# Sample functions from variational model to visualize fits.
rs = np.random.RandomState(0)
inputs = np.linspace(-5, 5, num=400, dtype=np.float32)
x = tf.expand_dims(inputs, 1)
mus = tf.stack(
    [neural_network(x, qW_0.sample(), qW_1.sample(),
                    qb_0.sample(), qb_1.sample())
     for _ in range(10)])

# %%
print(inputs.shape)
x
# Out:
# (400,)
# <tf.Tensor 'ExpandDims:0' shape=(400, 1) dtype=float32>

# %%
# FIRST VISUALIZATION (prior)

sess = ed.get_session()
tf.global_variables_initializer().run()
outputs = mus.eval()

fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111)
ax.set_title("Iteration: 0")
ax.plot(x_train, y_train, 'ks', alpha=0.5, label='(x, y)')
ax.plot(inputs, outputs[0].T, 'r', lw=2, alpha=0.5, label='prior draws')
ax.plot(inputs, outputs[1:].T, 'r', lw=2, alpha=0.5)
ax.set_xlim([-5, 5])
ax.set_ylim([-2, 2])
ax.legend()
plt.show()

# %%
outputs
# Out:
# array([[ 0.36577952,  0.3658004 ,  0.36582142, ...,  0.59709394,
#          0.59715545,  0.59721553],
#        [ 3.9175482 ,  3.9224024 ,  3.9272377 , ...,  0.77418065,
#          0.765291  ,  0.75662637],
#        [-0.08150375, -0.08062685, -0.07972753, ...,  0.08332044,
#          0.07784307,  0.07235003],
#        ...,
#        [-1.8097436 , -1.8097037 , -1.8096629 , ...,  2.170526  ,
#          2.173057  ,  2.1755152 ],
#        [ 2.9895504 ,  2.9882553 ,  2.9869344 , ..., -0.9653221 ,
#         -0.97188133, -0.9784154 ],
#        [ 2.115208  ,  2.1149096 ,  2.114607  , ..., -0.11261709,
#         -0.12279581, -0.13294335]], dtype=float32)

# %%
inference = ed.KLqp({W_0: qW_0, b_0: qb_0,
                     W_1: qW_1, b_1: qb_1}, data={y: y_train})
inference.run(n_iter=1000, n_samples=5)
# Out:
# /home/jjh/anaconda3/lib/python3.5/site-packages/edward/util/random_variables.py:53: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   not np.issubdtype(value.dtype, np.float) and \
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-d5998b53dc27> in <module>()
#       1 inference = ed.KLqp({W_0: qW_0, b_0: qb_0,
#       2                      W_1: qW_1, b_1: qb_1}, data={y: y_train})
# ----> 3 inference.run(n_iter=1000)
#
# /home/jjh/anaconda3/lib/python3.5/site-packages/edward/inferences/inference.py in run(self, variables, use_coordinator, *args, **kwargs)
#     123         Passed into `initialize`.
#     124     """
# --> 125     self.initialize(*args, **kwargs)
#     126
#     127     if variables is None:
#
# /home/jjh/anaconda3/lib/python3.5/site-packages/edward/inferences/klqp.py in initialize(self, n_samples, kl_scaling, *args, **kwargs)
#     108     self.n_samples = n_samples
#     109     self.kl_scaling = kl_scaling
# --> 110     return super(KLqp, self).initialize(*args, **kwargs)
#     111
#     112   def build_loss_and_gradients(self, var_list):
#
# /home/jjh/anaconda3/lib/python3.5/site-packages/edward/inferences/variational_inference.py in initialize(self, optimizer, var_list, use_prettytensor, global_step, *args, **kwargs)
#      66       var_list = list(var_list)
#      67
# ---> 68     self.loss, grads_and_vars = self.build_loss_and_gradients(var_list)
#      69
#      70     if self.logging:
#
# /home/jjh/anaconda3/lib/python3.5/site-packages/edward/inferences/klqp.py in build_loss_and_gradients(self, var_list)
#     143     if is_reparameterizable:
#     144       if is_analytic_kl:
# --> 145         return build_reparam_kl_loss_and_gradients(self, var_list)
#     146       # elif is_analytic_entropy:
#     147       #    return build_reparam_entropy_loss_and_gradients(self, var_list)
#
# /home/jjh/anaconda3/lib/python3.5/site-packages/edward/inferences/klqp.py in build_reparam_kl_loss_and_gradients(inference, var_list)
#     715     for z, qz in six.iteritems(inference.latent_vars):
#     716       # Copy q(z) to obtain new set of posterior samples.
# --> 717       qz_copy = copy(qz, scope=scope)
#     718       dict_swap[z] = qz_copy.value()
#     719
#
# /home/jjh/anaconda3/lib/python3.5/site-packages/edward/util/random_variables.py in copy(org_instance, dict_swap, scope, replace_itself, copy_q, copy_parent_rvs)
#     245       else:
#     246         kwargs[key] = _copy_default(
# --> 247             value, dict_swap, scope, True, copy_q, False)
#     248
#     249     kwargs['name'] = new_name
#
# /home/jjh/anaconda3/lib/python3.5/site-packages/edward/util/random_variables.py in _copy_default(x, *args, **kwargs)
#      87 def _copy_default(x, *args, **kwargs):
#      88   if isinstance(x, (RandomVariable, tf.Operation, tf.Tensor, tf.Variable)):
# ---> 89     x = copy(x, *args, **kwargs)
#      90
#      91   return x
#
# /home/jjh/anaconda3/lib/python3.5/site-packages/edward/util/random_variables.py in copy(org_instance, dict_swap, scope, replace_itself, copy_q, copy_parent_rvs)
#     269     # op. Therefore copy the op itself.
#     270     op = tensor.op
# --> 271     new_op = copy(op, dict_swap, scope, True, copy_q, False)
#     272
#     273     output_index = op.outputs.index(tensor)
#
# /home/jjh/anaconda3/lib/python3.5/site-packages/edward/util/random_variables.py in copy(org_instance, dict_swap, scope, replace_itself, copy_q, copy_parent_rvs)
#     315                           [],  # input types; will add them afterwards
#     316                           original_op,
# --> 317                           op_def)
#     318
#     319     # advertise op early to break recursions
#
# /home/jjh/anaconda3/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in __init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    1786       # Refactor so we don't have to do this here.
#    1787       grouped_inputs = self._reconstruct_sequence_inputs(
# -> 1788           op_def, inputs, node_def.attr)
#    1789       self._c_op = _create_c_op(self._graph, node_def, grouped_inputs,
#    1790                                 control_input_ops)
#
# /home/jjh/anaconda3/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in _reconstruct_sequence_inputs(self, op_def, inputs, attrs)
#    1845         grouped_inputs.append(inputs[i:i + input_len])
#    1846       else:
# -> 1847         grouped_inputs.append(inputs[i])
#    1848       i += input_len
#    1849
#
# IndexError: list index out of range
